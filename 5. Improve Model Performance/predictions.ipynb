# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in /home/user/anaconda3/lib/python3.10/site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in /home/user/anaconda3/lib/python3.10/site-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in /home/user/anaconda3/lib/python3.10/site-packages (from pytesseract) (9.4.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /home/user/anaconda3/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (65.6.3)
# Requirement already satisfied: packaging>=20.0 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/user/anaconda3/lib/python3.10/site-packages (from spacy) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/user/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/user/anaconda3/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/user/anaconda3/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/user/anaconda3/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/user/anaconda3/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/user/anaconda3/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import cv2
import pytesseract
from glob import glob
import spacy
import re
import string

# %%
def cleanText(txt):
    whitespace = string.whitespace
    punctuation= "!#$%&\'()*+:;<=>?[\\]^`{|}~"
    tablewhitespace = str.maketrans('','',whitespace)
    tablepunctuation = str.maketrans('','',punctuation)

    text = str(txt)
    text = text.lower()
    remvoewhitespace = text.translate(tablewhitespace)
    removepunctuation = remvoewhitespace.translate(tablepunctuation)
    return str(removepunctuation)

# %%
model_ner = spacy.load('../3. Train Named Entity Recognition/output/model-best')

# %%
# load image
image = cv2.imread('6.jpg')

# extract data
testData = pytesseract.image_to_data(image)

#convert data into content
test_list = list(map(lambda x: x.split('\t'), testData.split('\n')))
df = pd.DataFrame(test_list[1:], columns=test_list[0])
df.dropna(inplace=True)
df['text'] = df['text'].apply(cleanText)

#convertdata into content
dataClean = df.query("text != '' ")
content = " ".join([w for w in dataClean['text']])
print(content)

# get predictions from NER model

doc = model_ner(content)
# Out:
# cell 8099948528 te 8466045457 email lictsrikant@gmail.com life insurance corporation of india seosrikantht@gmail.com thathineni srikanth insurance advisor agent code no. 0316164y life insurance corporation of india br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018. lictsrikant8099948528.blogspot.in, interviewsinhyderabad.blogspot.in facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo

# %%
from spacy import displacy

# %%
# displacy.serve(doc, style='ent')

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cell
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8099948528
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  te
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8466045457
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  email
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seosrikantht@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thathineni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     srikanth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     advisor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#  agent code no. 0316164y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant8099948528.blogspot.in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-WEB</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     , interviewsinhyderabad.blogspot.in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-WEB</span>
# </mark>
#  facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo</div></span>

# %%
# Tagging

docjosn = doc.to_json()
docjosn.keys()
# Out:
# dict_keys(['text', 'ents', 'tokens'])

# %%
doc_text = docjosn['text']

# %%
dataframe_tokens = pd.DataFrame(docjosn['tokens'])
dataframe_tokens['token'] = dataframe_tokens[['start', 'end']].apply(
    lambda x: doc_text[x[0]:x[1]], axis=1)

# %%
dataframe_tokens.head()
# Out:
#    id  start  end       token
# 0   0      0    4        cell
# 1   1      5   15  8099948528
# 2   2     16   18          te
# 3   3     19   29  8466045457
# 4   4     30   35       email

# %%
right_table = pd.DataFrame(docjosn['ents'])[['start', 'label']]
dataframe_tokens = pd.merge(dataframe_tokens, right_table, how='left', on='start')

# %%
dataframe_tokens.fillna('O', inplace=True)
dataframe_tokens.head()
# Out:
#    id  start  end       token    label
# 0   0      0    4        cell        O
# 1   1      5   15  8099948528  B-PHONE
# 2   2     16   18          te        O
# 3   3     19   29  8466045457  B-PHONE
# 4   4     30   35       email        O

# %%
# join label to dataClean dataframe
dataClean['end'] = dataClean['text'].apply(lambda x : len(x)+1).cumsum() - 1
dataClean['start'] = dataClean[['text', 'end']].apply(lambda x: x[1] - len(x[0]), axis=1)
# Out:
# /tmp/ipykernel_5195/1829804590.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataClean['end'] = dataClean['text'].apply(lambda x : len(x)+1).cumsum() - 1
# /tmp/ipykernel_5195/1829804590.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataClean['start'] = dataClean[['text', 'end']].apply(lambda x: x[1] - len(x[0]), axis=1)

# %%
dataClean.head()
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 12     5        1         3       1        1        1  722   53    64     28
# 14     5        1         3       1        1        3  822   53   203     28
# 17     5        1         3       2        1        1   55   55    85     89
# 18     5        1         3       2        1        2  822   71   197     67
# 20     5        1         3       2        2        1  593  136    93     25
#
#    conf        text  end  start
# 12   92        cell    4      0
# 14   96  8099948528   15      5
# 17   31          te   18     16
# 18   94  8466045457   29     19
# 20   89       email   35     30

# %%
# inner join with start
datarame_info = pd.merge(dataClean, dataframe_tokens[['start', 'token', 'label']], how='inner', on='start')

# %%
datarame_info.head()
# Out:
#   level page_num block_num par_num line_num word_num left  top width height  \
# 0     5        1         3       1        1        1  722   53    64     28
# 1     5        1         3       1        1        3  822   53   203     28
# 2     5        1         3       2        1        1   55   55    85     89
# 3     5        1         3       2        1        2  822   71   197     67
# 4     5        1         3       2        2        1  593  136    93     25
#
#   conf        text  end  start       token    label
# 0   92        cell    4      0        cell        O
# 1   96  8099948528   15      5  8099948528  B-PHONE
# 2   31          te   18     16          te        O
# 3   94  8466045457   29     19  8466045457  B-PHONE
# 4   89       email   35     30       email        O

# %%
# Bounding BOx

# %%
bb_df = datarame_info.query("label != 'O' ")
bb_df.head()
# Out:
#   level page_num block_num par_num line_num word_num left  top width height  \
# 1     5        1         3       1        1        3  822   53   203     28
# 3     5        1         3       2        1        2  822   71   197     67
# 5     5        1         3       2        2        3  709  136   316     31
# 6     5        1         3       3        1        1   46  170    33     14
# 7     5        1         3       3        1        2   85  151    91     42
#
#   conf                   text  end  start                  token    label
# 1   96             8099948528   15      5             8099948528  B-PHONE
# 3   94             8466045457   29     19             8466045457  B-PHONE
# 5   88  lictsrikant@gmail.com   57     36  lictsrikant@gmail.com  B-EMAIL
# 6   96                   life   62     58                   life    B-ORG
# 7   94              insurance   72     63              insurance    I-ORG

# %%
img = image.copy()

# %%
for x,y,w,h,label in bb_df[['left', 'top', 'width', 'height', 'label']].values:
    x = int(x)
    y = int(y)
    w = int(w)
    h = int(h)
    
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)
    cv2.putText(img, str(label), (x,y), cv2.FONT_HERSHEY_PLAIN, 1, (255, 255, 0), 2)
    
cv2.imshow('Predictions', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)

# %%
bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
# Out:
# /tmp/ipykernel_5195/3914511576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])

# %%
# group the label

class groupgen():
    def __init__(self):
        self.id = 0
        self.text = ''
    
    def getgroup(self, text):
        if self.text == text:
            return self.id
        else:
            self.id +=1
            self.text = text
            return self.id

grp_gen = groupgen()

# %%
bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)
# Out:
# /tmp/ipykernel_5195/472836701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)

# %%
bb_df.head()
# Out:
#   level page_num block_num par_num line_num word_num left  top width height  \
# 1     5        1         3       1        1        3  822   53   203     28
# 3     5        1         3       2        1        2  822   71   197     67
# 5     5        1         3       2        2        3  709  136   316     31
# 6     5        1         3       3        1        1   46  170    33     14
# 7     5        1         3       3        1        2   85  151    91     42
#
#   conf                   text  end  start                  token  label  group
# 1   96             8099948528   15      5             8099948528  PHONE      1
# 3   94             8466045457   29     19             8466045457  PHONE      1
# 5   88  lictsrikant@gmail.com   57     36  lictsrikant@gmail.com  EMAIL      2
# 6   96                   life   62     58                   life    ORG      3
# 7   94              insurance   72     63              insurance    ORG      3

# %%
# right and bottom of bounding box
bb_df[['left', 'top', 'width', 'height']] = bb_df[['left', 'top', 'width', 'height']].astype(int)

bb_df['right'] = bb_df['left'] + bb_df['width']
bb_df['bottom'] = bb_df['top'] + bb_df['height']
# Out:
# /tmp/ipykernel_5195/3828079379.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df[['left', 'top', 'width', 'height']] = bb_df[['left', 'top', 'width', 'height']].astype(int)
# /tmp/ipykernel_5195/3828079379.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['right'] = bb_df['left'] + bb_df['width']
# /tmp/ipykernel_5195/3828079379.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['bottom'] = bb_df['top'] + bb_df['height']

# %%
# tagging: groupby group

col_group = ['left', 'top', 'right', 'bottom', 'label', 'token', 'group']
group_tag_img = bb_df[col_group].groupby(by='group')

# %%
img_tagging = group_tag_img.agg({
    'left': min,
    'right': max,
    'top': min,
    'bottom': max,
    'label': np.unique,
    'token': lambda x: " ".join(x)
})

# %%
img_tagging
# Out:
#        left  right  top  bottom    label                                token
# group
# 1       822   1025   53     138  [PHONE]                8099948528 8466045457
# 2       709   1025  136     167  [EMAIL]                lictsrikant@gmail.com
# 3        46    374  151     193    [ORG]  life insurance corporation of india
# 4       668   1025  163     209  [EMAIL]               seosrikantht@gmail.com
# 5       310    755  227     259   [NAME]                  thathineni srikanth
# 6       399    669  271     296    [DES]                    insurance advisor
# 7        47    882  395     427    [ORG]  life insurance corporation of india
# 8        46    476  506     533    [WEB]    lictsrikant8099948528.blogspot.in

# %%
img_bb = image.copy()
for l,r,t,b,label,token in img_tagging.values:
    cv2.rectangle(img_bb, (l,t), (r,b), (0,255,0),2)
    cv2.putText(img_bb, str(label), (l,t), cv2.FONT_HERSHEY_PLAIN, 1, (255,0,255), 2)

cv2.imshow("Bounding Box Business Card", img_bb)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)
#
# QObject::moveToThread: Current thread (0x6fed7b0) is not the object's thread (0x77d5cb0).
# Cannot move to target thread (0x6fed7b0)

# %%
# Parsing

# %%
def parser(text, label):
    if label == 'PHONE':
        text = text.lower()
        text = re.sub(r'\D', '', text)
        
    elif label == 'EMAIL':
        text = text.lower()
        allow_special = '@_.\-'
        text = re.sub(r'[^A-Za-z10-9{} ]'.format(allow_special),'',text)
    elif label == 'WEB':
        text = text.lower()
        allow_spe_cha = ':/.%#\-'
        text = re.sub(r'[^A-Za-z10-9{} ]'.format(allow_spe_cha),'',text)
    elif label in ('NAME', 'DES'):
        text = text.lower()
        text = re.sub(r'[^a-z ]','',text)
        text = text.title()
    elif label == 'ORG':
        text = text.lower()
        text = re.sub(r'[^a-z0-9 ]','',text)
        text = text.title()
    
    return text

# %%
parser('Faruk 3043740', 'NAME')
# Out:
# 'Faruk '

# %%
# entites

# %%
info_array = datarame_info[['token', 'label']].values
entities = dict(NAME=[], ORG=[],DES=[],PHONE=[],EMAIL=[],WEB=[])

previous = 'O'
for token, label in info_array:
    bio_tag = label[:1]
    label_tag = label[2:]
    # step -1 parse the token
    text = parser(token, label_tag)
    
    if bio_tag in ('B', 'I'):
        if previous != label_tag:
            entities[label_tag].append(text)
        else:
            if bio_tag == 'B':
                entities[label_tag].append(text)
            else:
                if label_tag in ("NAME", 'ORG', 'DES'):
                    entities[label_tag][-1] = entities[label_tag][-1] + " " + text
                else:
                    entities[label_tag][-1] = entities[label_tag][-1] + " " + text
    
    previous = label_tag

# %%
entities
# Out:
# {'NAME': ['Thathineni Srikanth'],
#  'ORG': ['Life Insurance Corporation Of India',
#   'Life Insurance Corporation Of India'],
#  'DES': ['Insurance Advisor'],
#  'PHONE': ['8099948528', '8466045457'],
#  'EMAIL': ['lictsrikant@gmail.com', 'seosrikantht@gmail.com'],
#  'WEB': ['lictsrikant8099948528.blogspot.in']}
